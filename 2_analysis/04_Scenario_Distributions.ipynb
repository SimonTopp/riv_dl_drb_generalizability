# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import dataframe_image as dfi
import geopandas as gpd

# %%
def reformat_prepped(prepped,seq_len,partition,llo_groups,scenario='Baseline'):
    x_data = prepped[f'x_{partition}'][:,-seq_len:,:]
    shape_x = x_data.shape
    x_data = x_data.reshape(shape_x[0]*shape_x[1],shape_x[2])
    x_data = x_data*prepped['x_std']+prepped['x_mean']
    dates= prepped[f'times_{partition}'][:,-seq_len:,:].reshape(shape_x[0]*shape_x[1])
    seg_ids = prepped[f'ids_{partition}'][:,-seq_len:,:].reshape(shape_x[0]*shape_x[1])
    x_vars = prepped['x_vars']
    df = pd.DataFrame(columns=x_vars, data=x_data)
    df['date']=pd.to_datetime(dates)
    df['month']=df['date'].dt.month
    df['sg_d_nt']=seg_ids
    if np.isin(scenario, ['Coastal','Headwaters','Appalachians']):
        if np.isin(partition,['trn','val']):
            df = df[~df.sg_d_nt.isin(llo_groups.seg_id_nat[llo_groups.test_group == scenario])]
        elif partition == 'tst':
            df = df[df.sg_d_nt.isin(llo_groups.seg_id_nat[llo_groups.test_group == scenario])]
    return df

def calc_diff_temp(tst,trn):
    return tst['seg_tave_air'][tst.month.isin([6,7,8])].median()-trn['seg_tave_air'][trn.month.isin([6,7,8])].median()

def calc_diff_precip(tst,trn):
    return tst['seg_rain'].median()-trn['seg_rain'].median()

# %%
llo_groups = pd.read_csv('data_DRB/DRB_spatial/llo_groups.csv')
llo_groups.loc[llo_groups.test_group == 'Piedmont', 'test_group']='Headwaters'
llo_groups.loc[llo_groups.test_group == 'Coastal_Plains', 'test_group']='Coastal'
llo_groups['test_group'].unique()
# Out:
# array(['Coastal', 'Appalachians', 'Headwaters'], dtype=object)

# %%
baseline_trn = reformat_prepped(np.load("results/baseline/GWN/prepped.npz"),15,'trn',llo_groups)
lto_max_trn = reformat_prepped(np.load("results/LTO/max/GWN/prepped.npz"),15,'trn', llo_groups)
drought_trn = reformat_prepped(np.load("results/Drought/GWN/prepped.npz"),15,'trn', llo_groups)
app_trn = reformat_prepped(np.load("results/LLO/appalachians/GWN/prepped.npz"),15,'trn',llo_groups, 'Appalachians')
head_trn = reformat_prepped(np.load("results/LLO/piedmont/GWN/prepped.npz"),15,'trn',llo_groups, 'Headwaters') #Piedmont misslabled in prep script, need to correct
coast_trn = reformat_prepped(np.load("results/LLO/coastal/GWN/prepped.npz"),15,'trn',llo_groups, 'Coastal')

baseline_val = reformat_prepped(np.load("results/baseline/GWN/prepped.npz"),15,'val', llo_groups)
lto_max_val = reformat_prepped(np.load("results/LTO/max/GWN/prepped.npz"),15,'val', llo_groups)
drought_val = reformat_prepped(np.load("results/Drought/GWN/prepped.npz"),15,'val', llo_groups)
app_val = reformat_prepped(np.load("results/LLO/appalachians/GWN/prepped.npz"),15,'val', llo_groups, 'Appalachians')
head_val = reformat_prepped(np.load("results/LLO/piedmont/GWN/prepped.npz"),15,'val', 'Headwaters') #Piedmont misslabled in prep script, need to correct
coast_val = reformat_prepped(np.load("results/LLO/coastal/GWN/prepped.npz"),15,'val', 'Coastal')

baseline_tst = reformat_prepped(np.load("results/baseline/GWN/prepped.npz"),15,'tst', llo_groups)
lto_max_tst = reformat_prepped(np.load("results/LTO/max/GWN/prepped.npz"),15,'tst', llo_groups)
drought_tst = reformat_prepped(np.load("results/Drought/GWN/prepped.npz"),15,'tst', llo_groups)
app_tst = reformat_prepped(np.load("results/LLO/appalachians/GWN/prepped.npz"),15,'tst',llo_groups, 'Appalachians')
head_tst = reformat_prepped(np.load("results/LLO/piedmont/GWN/prepped.npz"),15,'tst',llo_groups, 'Headwaters') #Piedmont misslabled in prep script, need to correct
coast_tst = reformat_prepped(np.load("results/LLO/coastal/GWN/prepped.npz"),15,'tst', llo_groups, 'Coastal')

# %%
base_diff = calc_diff_temp(baseline_tst,baseline_trn)
max_diff= calc_diff_temp(lto_max_tst,lto_max_trn)
drought_diff = calc_diff_temp(drought_tst,drought_trn)

# %%
plt.style.use('default')
plt.style.use('seaborn-colorblind')

pal = list(sns.color_palette('colorblind',4))

fig, ax = plt.subplots(2,1,figsize=(4,3.5), constrained_layout=True, dpi=200,sharey=True,sharex=True)

#sns.kdeplot(lto_min['seg_tave_air'][lto_min.month.isin([6,7,8])],ax=ax[0],label=f'Test',color = pal[0])
#sns.kdeplot(lto_min_trn['seg_tave_air'][lto_min_trn.month.isin([6,7,8])],ax=ax[0],label=f'Train',color = pal[1])
#ax[0].axvline(lto_min['seg_tave_air'][lto_min.month.isin([6,7,8])].median(),color=pal[0], alpha = .5)
#ax[0].axvline(lto_min_trn['seg_tave_air'][lto_min_trn.month.isin([6,7,8])].median(),color = pal[1],alpha=.5)
#ax[0].set_title('Train Hot/Test Cold')
#ax[0].set_ylabel('')

sns.kdeplot(lto_max_tst['seg_tave_air'][lto_max_tst.month.isin([6,7,8])],ax=ax[0],label=f'Test',color = pal[0])
sns.kdeplot(lto_max_trn['seg_tave_air'][lto_max_trn.month.isin([6,7,8])],ax=ax[0],label=f'Train',color = pal[1])
#ax[0].set_title('')
ax[0].axvline(lto_max_tst['seg_tave_air'][lto_max_tst.month.isin([6,7,8])].median(),color=pal[0], alpha = .5)
ax[0].axvline(lto_max_trn['seg_tave_air'][lto_max_trn.month.isin([6,7,8])].median(),color = pal[1],alpha=.5)
ax[0].set_ylabel('Warming\nScenario')

sns.kdeplot(baseline_tst['seg_tave_air'][baseline_tst.month.isin([6,7,8])],ax=ax[1],label=f'Test',color = pal[0])
sns.kdeplot(baseline_trn['seg_tave_air'][baseline_trn.month.isin([6,7,8])],ax=ax[1],label=f'Train',color = pal[1])
#ax[1].set_title('')
ax[1].axvline(baseline_tst['seg_tave_air'][baseline_tst.month.isin([6,7,8])].median(),color=pal[0], alpha = .5)
ax[1].axvline(baseline_trn['seg_tave_air'][baseline_trn.month.isin([6,7,8])].median(),color = pal[1],alpha=.5)
ax[1].set_ylabel('Baseline\nScenario')

ax[1].set_xlabel('Air Temp °C')
ax[1].annotate(f'Δ°C={base_diff:.2f}', xy=(3,.05))
ax[0].annotate(f'Δ°C={max_diff:.2f}', xy=(3,.05))
#ax[0].annotate(f'Δ°C={min_diff:.2f}', xy=(3,.05))

plt.yticks([])
ax[0].legend(loc='upper right')
plt.savefig('results/figures/temp_distributions_warming_baseline.png',dpi=200)

# %%
def reformat_precip(scenario1,scenario2,name1,name2):
    scenario1['run']=name1
    scenario2['run']=name2
    df = pd.concat([scenario1,scenario2],ignore_index=True)
    df['year'] = temp_df.date.dt.year.where(temp_df.date.dt.month < 10,temp_df.date.dt.year + 1)
    df = drought_df.groupby(['run','year','date']).mean().groupby(['run','year']).sum()

# %%
def reformat_precip(tst,trn):
    tst['Partition']='Test'
    trn['Partition']='Train'
    df = pd.concat([tst,trn],ignore_index=True)
    df['year']=df.date.dt.year.where(df.date.dt.month < 10,df.date.dt.year + 1)
    df = df.groupby(['Partition','year','date']).mean().groupby(['Partition','year']).sum()
    return df.reset_index()

   
fig, ax = plt.subplots(1,2,figsize=(4,3),dpi=200,constrained_layout=True,sharey=True,sharex=True)
sns.boxplot(data=reformat_precip(drought_tst,drought_trn), x='Partition', y='seg_rain',ax=ax[0],order=['Train','Test'], palette=[pal[1],pal[0]])#,label=f'Drought',color = pal[0])
ax[0].set_ylabel('Annual Rainfall (m)')
ax[0].set_xlabel('Drought Scenario')

sns.boxplot(data=reformat_precip(baseline_tst,baseline_trn), x='Partition', y='seg_rain',ax=ax[1],order=['Train','Test'], palette=[pal[1],pal[0]])
ax[1].set_ylabel('')
ax[1].set_xlabel('Baseline')
plt.savefig('results/figures/precip_distributions_warming_baseline.png',dpi=200)

# %%
precip_df = reformat_precip(drought_tst,drought_trn)

# %%
precip_df.groupby(['Partition']).median()
# Out:
#              year  seg_slope      seg_elev  seg_width_mean  seg_tave_air  \
# Partition
# Test       1990.5   1.803479  54072.800659    11372.766421   3707.604290
# Train      1999.0   1.803479  54072.800659    11372.766421   3747.586891
#
#            seginc_swrad  seg_rain  seginc_potet   month       sg_d_nt
# Partition
# Test       53501.858438  0.958978     32.002281  2382.0  739019.10989
# Train      52970.176983  1.147006     31.816809  2382.0  739019.10989

# %%
def my_styler_correct(s):
    if s.name[1]=='Test':
        return ["background-color: #AAAAAA"] * len(s)
    elif s.name[1]=='Train':
        return ["background-color: #CCCCCC"] * len(s)
    else:
        return ["background-color: #EEEEEE"] * len(s)
    
def format_run_tables(trn,val,tst,run):
    ## Train
    trn = (trn.describe()[['seg_slope','seg_elev','seg_width_mean','seg_tave_air','seginc_swrad','seg_rain','seginc_potet']].filter(items=['min','25%','50%','75%','max'],axis=0)
           .assign(Partition='Train'))
    
    tst = (tst.describe()[['seg_slope','seg_elev','seg_width_mean','seg_tave_air','seginc_swrad','seg_rain','seginc_potet']].filter(items=['min','25%','50%','75%','max'],axis=0)
           .assign(Partition='Test'))
    
    val = (val.describe()[['seg_slope','seg_elev','seg_width_mean','seg_tave_air','seginc_swrad','seg_rain','seginc_potet']].filter(items=['min','25%','50%','75%','max'],axis=0)
           .assign(Partition='Val'))

    table_out = (pd.concat([trn,tst,val])
                     .rename(columns={'seg_slope':'Slope (m/km)','seg_elev':'Elevation (m)','seg_width_mean':'Mean Width (m)',
                          'seg_tave_air':'Air Temp. (°C)','seginc_swrad':'SW Rad. (W/sq.m)','seg_rain':'Precip. (cm)','seginc_potet':'Potential ET (cm)'})
                     .assign(**{'Precip. (cm)':(lambda x: x['Precip. (cm)']*100)},
                             **{'Potential ET (cm)':(lambda x: x['Potential ET (cm)']*100)})
                     .round(3)
                     .reset_index()
                     .assign(Percentile=lambda x:pd.Categorical(x['index'],ordered=True, categories = ['min','25%','50%','75%','max']))
                     .drop(columns=['index'])
                     .pivot(columns=['Partition'],index=['Percentile']))
    
    table_styled = table_out.style.apply(my_styler_correct).format(precision=2).set_caption(run).set_table_styles([{
    'selector': 'caption',
    'props': [
        ('weight', 'bold'),
        ('font-size', '18px')
        ]
    }])

    #dfi.export(table_styled, f'results/figures/{run}_summary.png', table_conversion='matplotlib')
    return table_styled

# %%
format_run_tables(baseline_trn,baseline_val,baseline_tst, 'Baseline')
# Out:
# <style type="text/css">
# #T_39b7e caption {
#   weight: bold;
#   font-size: 18px;
# }
# #T_39b7e_row0_col0, #T_39b7e_row0_col3, #T_39b7e_row0_col6, #T_39b7e_row0_col9, #T_39b7e_row0_col12, #T_39b7e_row0_col15, #T_39b7e_row0_col18, #T_39b7e_row1_col0, #T_39b7e_row1_col3, #T_39b7e_row1_col6, #T_39b7e_row1_col9, #T_39b7e_row1_col12, #T_39b7e_row1_col15, #T_39b7e_row1_col18, #T_39b7e_row2_col0, #T_39b7e_row2_col3, #T_39b7e_row2_col6, #T_39b7e_row2_col9, #T_39b7e_row2_col12, #T_39b7e_row2_col15, #T_39b7e_row2_col18, #T_39b7e_row3_col0, #T_39b7e_row3_col3, #T_39b7e_row3_col6, #T_39b7e_row3_col9, #T_39b7e_row3_col12, #T_39b7e_row3_col15, #T_39b7e_row3_col18, #T_39b7e_row4_col0, #T_39b7e_row4_col3, #T_39b7e_row4_col6, #T_39b7e_row4_col9, #T_39b7e_row4_col12, #T_39b7e_row4_col15, #T_39b7e_row4_col18 {
#   background-color: #AAAAAA;
# }
# #T_39b7e_row0_col1, #T_39b7e_row0_col4, #T_39b7e_row0_col7, #T_39b7e_row0_col10, #T_39b7e_row0_col13, #T_39b7e_row0_col16, #T_39b7e_row0_col19, #T_39b7e_row1_col1, #T_39b7e_row1_col4, #T_39b7e_row1_col7, #T_39b7e_row1_col10, #T_39b7e_row1_col13, #T_39b7e_row1_col16, #T_39b7e_row1_col19, #T_39b7e_row2_col1, #T_39b7e_row2_col4, #T_39b7e_row2_col7, #T_39b7e_row2_col10, #T_39b7e_row2_col13, #T_39b7e_row2_col16, #T_39b7e_row2_col19, #T_39b7e_row3_col1, #T_39b7e_row3_col4, #T_39b7e_row3_col7, #T_39b7e_row3_col10, #T_39b7e_row3_col13, #T_39b7e_row3_col16, #T_39b7e_row3_col19, #T_39b7e_row4_col1, #T_39b7e_row4_col4, #T_39b7e_row4_col7, #T_39b7e_row4_col10, #T_39b7e_row4_col13, #T_39b7e_row4_col16, #T_39b7e_row4_col19 {
#   background-color: #CCCCCC;
# }
# #T_39b7e_row0_col2, #T_39b7e_row0_col5, #T_39b7e_row0_col8, #T_39b7e_row0_col11, #T_39b7e_row0_col14, #T_39b7e_row0_col17, #T_39b7e_row0_col20, #T_39b7e_row1_col2, #T_39b7e_row1_col5, #T_39b7e_row1_col8, #T_39b7e_row1_col11, #T_39b7e_row1_col14, #T_39b7e_row1_col17, #T_39b7e_row1_col20, #T_39b7e_row2_col2, #T_39b7e_row2_col5, #T_39b7e_row2_col8, #T_39b7e_row2_col11, #T_39b7e_row2_col14, #T_39b7e_row2_col17, #T_39b7e_row2_col20, #T_39b7e_row3_col2, #T_39b7e_row3_col5, #T_39b7e_row3_col8, #T_39b7e_row3_col11, #T_39b7e_row3_col14, #T_39b7e_row3_col17, #T_39b7e_row3_col20, #T_39b7e_row4_col2, #T_39b7e_row4_col5, #T_39b7e_row4_col8, #T_39b7e_row4_col11, #T_39b7e_row4_col14, #T_39b7e_row4_col17, #T_39b7e_row4_col20 {
#   background-color: #EEEEEE;
# }
# </style>
# <table id="T_39b7e">
#   <caption>Baseline</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39b7e_level0_col0" class="col_heading level0 col0" colspan="3">Slope (m/km)</th>
#       <th id="T_39b7e_level0_col3" class="col_heading level0 col3" colspan="3">Elevation (m)</th>
#       <th id="T_39b7e_level0_col6" class="col_heading level0 col6" colspan="3">Mean Width (m)</th>
#       <th id="T_39b7e_level0_col9" class="col_heading level0 col9" colspan="3">Air Temp. (°C)</th>
#       <th id="T_39b7e_level0_col12" class="col_heading level0 col12" colspan="3">SW Rad. (W/sq.m)</th>
#       <th id="T_39b7e_level0_col15" class="col_heading level0 col15" colspan="3">Precip. (cm)</th>
#       <th id="T_39b7e_level0_col18" class="col_heading level0 col18" colspan="3">Potential ET (cm)</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Partition</th>
#       <th id="T_39b7e_level1_col0" class="col_heading level1 col0" >Test</th>
#       <th id="T_39b7e_level1_col1" class="col_heading level1 col1" >Train</th>
#       <th id="T_39b7e_level1_col2" class="col_heading level1 col2" >Val</th>
#       <th id="T_39b7e_level1_col3" class="col_heading level1 col3" >Test</th>
#       <th id="T_39b7e_level1_col4" class="col_heading level1 col4" >Train</th>
#       <th id="T_39b7e_level1_col5" class="col_heading level1 col5" >Val</th>
#       <th id="T_39b7e_level1_col6" class="col_heading level1 col6" >Test</th>
#       <th id="T_39b7e_level1_col7" class="col_heading level1 col7" >Train</th>
#       <th id="T_39b7e_level1_col8" class="col_heading level1 col8" >Val</th>
#       <th id="T_39b7e_level1_col9" class="col_heading level1 col9" >Test</th>
#       <th id="T_39b7e_level1_col10" class="col_heading level1 col10" >Train</th>
#       <th id="T_39b7e_level1_col11" class="col_heading level1 col11" >Val</th>
#       <th id="T_39b7e_level1_col12" class="col_heading level1 col12" >Test</th>
#       <th id="T_39b7e_level1_col13" class="col_heading level1 col13" >Train</th>
#       <th id="T_39b7e_level1_col14" class="col_heading level1 col14" >Val</th>
#       <th id="T_39b7e_level1_col15" class="col_heading level1 col15" >Test</th>
#       <th id="T_39b7e_level1_col16" class="col_heading level1 col16" >Train</th>
#       <th id="T_39b7e_level1_col17" class="col_heading level1 col17" >Val</th>
#       <th id="T_39b7e_level1_col18" class="col_heading level1 col18" >Test</th>
#       <th id="T_39b7e_level1_col19" class="col_heading level1 col19" >Train</th>
#       <th id="T_39b7e_level1_col20" class="col_heading level1 col20" >Val</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Percentile</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39b7e_level0_row0" class="row_heading level0 row0" >min</th>
#       <td id="T_39b7e_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_39b7e_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_39b7e_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_39b7e_row0_col3" class="data row0 col3" >-1.20</td>
#       <td id="T_39b7e_row0_col4" class="data row0 col4" >-1.20</td>
#       <td id="T_39b7e_row0_col5" class="data row0 col5" >-1.20</td>
#       <td id="T_39b7e_row0_col6" class="data row0 col6" >8.80</td>
#       <td id="T_39b7e_row0_col7" class="data row0 col7" >8.80</td>
#       <td id="T_39b7e_row0_col8" class="data row0 col8" >8.80</td>
#       <td id="T_39b7e_row0_col9" class="data row0 col9" >-24.33</td>
#       <td id="T_39b7e_row0_col10" class="data row0 col10" >-26.15</td>
#       <td id="T_39b7e_row0_col11" class="data row0 col11" >-19.17</td>
#       <td id="T_39b7e_row0_col12" class="data row0 col12" >0.00</td>
#       <td id="T_39b7e_row0_col13" class="data row0 col13" >0.00</td>
#       <td id="T_39b7e_row0_col14" class="data row0 col14" >0.00</td>
#       <td id="T_39b7e_row0_col15" class="data row0 col15" >0.00</td>
#       <td id="T_39b7e_row0_col16" class="data row0 col16" >0.00</td>
#       <td id="T_39b7e_row0_col17" class="data row0 col17" >0.00</td>
#       <td id="T_39b7e_row0_col18" class="data row0 col18" >0.00</td>
#       <td id="T_39b7e_row0_col19" class="data row0 col19" >0.00</td>
#       <td id="T_39b7e_row0_col20" class="data row0 col20" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_39b7e_level0_row1" class="row_heading level0 row1" >25%</th>
#       <td id="T_39b7e_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_39b7e_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_39b7e_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_39b7e_row1_col3" class="data row1 col3" >12.44</td>
#       <td id="T_39b7e_row1_col4" class="data row1 col4" >12.44</td>
#       <td id="T_39b7e_row1_col5" class="data row1 col5" >12.44</td>
#       <td id="T_39b7e_row1_col6" class="data row1 col6" >21.32</td>
#       <td id="T_39b7e_row1_

# %%
format_run_tables(lto_max_trn,lto_max_val,lto_max_tst,'Warming')
# Out:
# <style type="text/css">
# #T_23729 caption {
#   weight: bold;
#   font-size: 18px;
# }
# #T_23729_row0_col0, #T_23729_row0_col3, #T_23729_row0_col6, #T_23729_row0_col9, #T_23729_row0_col12, #T_23729_row0_col15, #T_23729_row0_col18, #T_23729_row1_col0, #T_23729_row1_col3, #T_23729_row1_col6, #T_23729_row1_col9, #T_23729_row1_col12, #T_23729_row1_col15, #T_23729_row1_col18, #T_23729_row2_col0, #T_23729_row2_col3, #T_23729_row2_col6, #T_23729_row2_col9, #T_23729_row2_col12, #T_23729_row2_col15, #T_23729_row2_col18, #T_23729_row3_col0, #T_23729_row3_col3, #T_23729_row3_col6, #T_23729_row3_col9, #T_23729_row3_col12, #T_23729_row3_col15, #T_23729_row3_col18, #T_23729_row4_col0, #T_23729_row4_col3, #T_23729_row4_col6, #T_23729_row4_col9, #T_23729_row4_col12, #T_23729_row4_col15, #T_23729_row4_col18 {
#   background-color: #AAAAAA;
# }
# #T_23729_row0_col1, #T_23729_row0_col4, #T_23729_row0_col7, #T_23729_row0_col10, #T_23729_row0_col13, #T_23729_row0_col16, #T_23729_row0_col19, #T_23729_row1_col1, #T_23729_row1_col4, #T_23729_row1_col7, #T_23729_row1_col10, #T_23729_row1_col13, #T_23729_row1_col16, #T_23729_row1_col19, #T_23729_row2_col1, #T_23729_row2_col4, #T_23729_row2_col7, #T_23729_row2_col10, #T_23729_row2_col13, #T_23729_row2_col16, #T_23729_row2_col19, #T_23729_row3_col1, #T_23729_row3_col4, #T_23729_row3_col7, #T_23729_row3_col10, #T_23729_row3_col13, #T_23729_row3_col16, #T_23729_row3_col19, #T_23729_row4_col1, #T_23729_row4_col4, #T_23729_row4_col7, #T_23729_row4_col10, #T_23729_row4_col13, #T_23729_row4_col16, #T_23729_row4_col19 {
#   background-color: #CCCCCC;
# }
# #T_23729_row0_col2, #T_23729_row0_col5, #T_23729_row0_col8, #T_23729_row0_col11, #T_23729_row0_col14, #T_23729_row0_col17, #T_23729_row0_col20, #T_23729_row1_col2, #T_23729_row1_col5, #T_23729_row1_col8, #T_23729_row1_col11, #T_23729_row1_col14, #T_23729_row1_col17, #T_23729_row1_col20, #T_23729_row2_col2, #T_23729_row2_col5, #T_23729_row2_col8, #T_23729_row2_col11, #T_23729_row2_col14, #T_23729_row2_col17, #T_23729_row2_col20, #T_23729_row3_col2, #T_23729_row3_col5, #T_23729_row3_col8, #T_23729_row3_col11, #T_23729_row3_col14, #T_23729_row3_col17, #T_23729_row3_col20, #T_23729_row4_col2, #T_23729_row4_col5, #T_23729_row4_col8, #T_23729_row4_col11, #T_23729_row4_col14, #T_23729_row4_col17, #T_23729_row4_col20 {
#   background-color: #EEEEEE;
# }
# </style>
# <table id="T_23729">
#   <caption>Warming</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23729_level0_col0" class="col_heading level0 col0" colspan="3">Slope (m/km)</th>
#       <th id="T_23729_level0_col3" class="col_heading level0 col3" colspan="3">Elevation (m)</th>
#       <th id="T_23729_level0_col6" class="col_heading level0 col6" colspan="3">Mean Width (m)</th>
#       <th id="T_23729_level0_col9" class="col_heading level0 col9" colspan="3">Air Temp. (°C)</th>
#       <th id="T_23729_level0_col12" class="col_heading level0 col12" colspan="3">SW Rad. (W/sq.m)</th>
#       <th id="T_23729_level0_col15" class="col_heading level0 col15" colspan="3">Precip. (cm)</th>
#       <th id="T_23729_level0_col18" class="col_heading level0 col18" colspan="3">Potential ET (cm)</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Partition</th>
#       <th id="T_23729_level1_col0" class="col_heading level1 col0" >Test</th>
#       <th id="T_23729_level1_col1" class="col_heading level1 col1" >Train</th>
#       <th id="T_23729_level1_col2" class="col_heading level1 col2" >Val</th>
#       <th id="T_23729_level1_col3" class="col_heading level1 col3" >Test</th>
#       <th id="T_23729_level1_col4" class="col_heading level1 col4" >Train</th>
#       <th id="T_23729_level1_col5" class="col_heading level1 col5" >Val</th>
#       <th id="T_23729_level1_col6" class="col_heading level1 col6" >Test</th>
#       <th id="T_23729_level1_col7" class="col_heading level1 col7" >Train</th>
#       <th id="T_23729_level1_col8" class="col_heading level1 col8" >Val</th>
#       <th id="T_23729_level1_col9" class="col_heading level1 col9" >Test</th>
#       <th id="T_23729_level1_col10" class="col_heading level1 col10" >Train</th>
#       <th id="T_23729_level1_col11" class="col_heading level1 col11" >Val</th>
#       <th id="T_23729_level1_col12" class="col_heading level1 col12" >Test</th>
#       <th id="T_23729_level1_col13" class="col_heading level1 col13" >Train</th>
#       <th id="T_23729_level1_col14" class="col_heading level1 col14" >Val</th>
#       <th id="T_23729_level1_col15" class="col_heading level1 col15" >Test</th>
#       <th id="T_23729_level1_col16" class="col_heading level1 col16" >Train</th>
#       <th id="T_23729_level1_col17" class="col_heading level1 col17" >Val</th>
#       <th id="T_23729_level1_col18" class="col_heading level1 col18" >Test</th>
#       <th id="T_23729_level1_col19" class="col_heading level1 col19" >Train</th>
#       <th id="T_23729_level1_col20" class="col_heading level1 col20" >Val</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Percentile</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23729_level0_row0" class="row_heading level0 row0" >min</th>
#       <td id="T_23729_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_23729_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_23729_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_23729_row0_col3" class="data row0 col3" >-1.20</td>
#       <td id="T_23729_row0_col4" class="data row0 col4" >-1.20</td>
#       <td id="T_23729_row0_col5" class="data row0 col5" >-1.20</td>
#       <td id="T_23729_row0_col6" class="data row0 col6" >8.80</td>
#       <td id="T_23729_row0_col7" class="data row0 col7" >8.80</td>
#       <td id="T_23729_row0_col8" class="data row0 col8" >8.80</td>
#       <td id="T_23729_row0_col9" class="data row0 col9" >-23.80</td>
#       <td id="T_23729_row0_col10" class="data row0 col10" >-26.15</td>
#       <td id="T_23729_row0_col11" class="data row0 col11" >-22.31</td>
#       <td id="T_23729_row0_col12" class="data row0 col12" >0.00</td>
#       <td id="T_23729_row0_col13" class="data row0 col13" >0.00</td>
#       <td id="T_23729_row0_col14" class="data row0 col14" >0.00</td>
#       <td id="T_23729_row0_col15" class="data row0 col15" >0.00</td>
#       <td id="T_23729_row0_col16" class="data row0 col16" >0.00</td>
#       <td id="T_23729_row0_col17" class="data row0 col17" >0.00</td>
#       <td id="T_23729_row0_col18" class="data row0 col18" >0.00</td>
#       <td id="T_23729_row0_col19" class="data row0 col19" >0.00</td>
#       <td id="T_23729_row0_col20" class="data row0 col20" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_23729_level0_row1" class="row_heading level0 row1" >25%</th>
#       <td id="T_23729_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_23729_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_23729_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_23729_row1_col3" class="data row1 col3" >12.44</td>
#       <td id="T_23729_row1_col4" class="data row1 col4" >12.44</td>
#       <td id="T_23729_row1_col5" class="data row1 col5" >12.44</td>
#       <td id="T_23729_row1_col6" class="data row1 col6" >21.32</td>
#       <td id="T_23729_row1_c

# %%
format_run_tables(drought_trn,drought_val,drought_tst,'Drought')
# Out:
# <style type="text/css">
# #T_ebbd5 caption {
#   weight: bold;
#   font-size: 18px;
# }
# #T_ebbd5_row0_col0, #T_ebbd5_row0_col3, #T_ebbd5_row0_col6, #T_ebbd5_row0_col9, #T_ebbd5_row0_col12, #T_ebbd5_row0_col15, #T_ebbd5_row0_col18, #T_ebbd5_row1_col0, #T_ebbd5_row1_col3, #T_ebbd5_row1_col6, #T_ebbd5_row1_col9, #T_ebbd5_row1_col12, #T_ebbd5_row1_col15, #T_ebbd5_row1_col18, #T_ebbd5_row2_col0, #T_ebbd5_row2_col3, #T_ebbd5_row2_col6, #T_ebbd5_row2_col9, #T_ebbd5_row2_col12, #T_ebbd5_row2_col15, #T_ebbd5_row2_col18, #T_ebbd5_row3_col0, #T_ebbd5_row3_col3, #T_ebbd5_row3_col6, #T_ebbd5_row3_col9, #T_ebbd5_row3_col12, #T_ebbd5_row3_col15, #T_ebbd5_row3_col18, #T_ebbd5_row4_col0, #T_ebbd5_row4_col3, #T_ebbd5_row4_col6, #T_ebbd5_row4_col9, #T_ebbd5_row4_col12, #T_ebbd5_row4_col15, #T_ebbd5_row4_col18 {
#   background-color: #AAAAAA;
# }
# #T_ebbd5_row0_col1, #T_ebbd5_row0_col4, #T_ebbd5_row0_col7, #T_ebbd5_row0_col10, #T_ebbd5_row0_col13, #T_ebbd5_row0_col16, #T_ebbd5_row0_col19, #T_ebbd5_row1_col1, #T_ebbd5_row1_col4, #T_ebbd5_row1_col7, #T_ebbd5_row1_col10, #T_ebbd5_row1_col13, #T_ebbd5_row1_col16, #T_ebbd5_row1_col19, #T_ebbd5_row2_col1, #T_ebbd5_row2_col4, #T_ebbd5_row2_col7, #T_ebbd5_row2_col10, #T_ebbd5_row2_col13, #T_ebbd5_row2_col16, #T_ebbd5_row2_col19, #T_ebbd5_row3_col1, #T_ebbd5_row3_col4, #T_ebbd5_row3_col7, #T_ebbd5_row3_col10, #T_ebbd5_row3_col13, #T_ebbd5_row3_col16, #T_ebbd5_row3_col19, #T_ebbd5_row4_col1, #T_ebbd5_row4_col4, #T_ebbd5_row4_col7, #T_ebbd5_row4_col10, #T_ebbd5_row4_col13, #T_ebbd5_row4_col16, #T_ebbd5_row4_col19 {
#   background-color: #CCCCCC;
# }
# #T_ebbd5_row0_col2, #T_ebbd5_row0_col5, #T_ebbd5_row0_col8, #T_ebbd5_row0_col11, #T_ebbd5_row0_col14, #T_ebbd5_row0_col17, #T_ebbd5_row0_col20, #T_ebbd5_row1_col2, #T_ebbd5_row1_col5, #T_ebbd5_row1_col8, #T_ebbd5_row1_col11, #T_ebbd5_row1_col14, #T_ebbd5_row1_col17, #T_ebbd5_row1_col20, #T_ebbd5_row2_col2, #T_ebbd5_row2_col5, #T_ebbd5_row2_col8, #T_ebbd5_row2_col11, #T_ebbd5_row2_col14, #T_ebbd5_row2_col17, #T_ebbd5_row2_col20, #T_ebbd5_row3_col2, #T_ebbd5_row3_col5, #T_ebbd5_row3_col8, #T_ebbd5_row3_col11, #T_ebbd5_row3_col14, #T_ebbd5_row3_col17, #T_ebbd5_row3_col20, #T_ebbd5_row4_col2, #T_ebbd5_row4_col5, #T_ebbd5_row4_col8, #T_ebbd5_row4_col11, #T_ebbd5_row4_col14, #T_ebbd5_row4_col17, #T_ebbd5_row4_col20 {
#   background-color: #EEEEEE;
# }
# </style>
# <table id="T_ebbd5">
#   <caption>Drought</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebbd5_level0_col0" class="col_heading level0 col0" colspan="3">Slope (m/km)</th>
#       <th id="T_ebbd5_level0_col3" class="col_heading level0 col3" colspan="3">Elevation (m)</th>
#       <th id="T_ebbd5_level0_col6" class="col_heading level0 col6" colspan="3">Mean Width (m)</th>
#       <th id="T_ebbd5_level0_col9" class="col_heading level0 col9" colspan="3">Air Temp. (°C)</th>
#       <th id="T_ebbd5_level0_col12" class="col_heading level0 col12" colspan="3">SW Rad. (W/sq.m)</th>
#       <th id="T_ebbd5_level0_col15" class="col_heading level0 col15" colspan="3">Precip. (cm)</th>
#       <th id="T_ebbd5_level0_col18" class="col_heading level0 col18" colspan="3">Potential ET (cm)</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Partition</th>
#       <th id="T_ebbd5_level1_col0" class="col_heading level1 col0" >Test</th>
#       <th id="T_ebbd5_level1_col1" class="col_heading level1 col1" >Train</th>
#       <th id="T_ebbd5_level1_col2" class="col_heading level1 col2" >Val</th>
#       <th id="T_ebbd5_level1_col3" class="col_heading level1 col3" >Test</th>
#       <th id="T_ebbd5_level1_col4" class="col_heading level1 col4" >Train</th>
#       <th id="T_ebbd5_level1_col5" class="col_heading level1 col5" >Val</th>
#       <th id="T_ebbd5_level1_col6" class="col_heading level1 col6" >Test</th>
#       <th id="T_ebbd5_level1_col7" class="col_heading level1 col7" >Train</th>
#       <th id="T_ebbd5_level1_col8" class="col_heading level1 col8" >Val</th>
#       <th id="T_ebbd5_level1_col9" class="col_heading level1 col9" >Test</th>
#       <th id="T_ebbd5_level1_col10" class="col_heading level1 col10" >Train</th>
#       <th id="T_ebbd5_level1_col11" class="col_heading level1 col11" >Val</th>
#       <th id="T_ebbd5_level1_col12" class="col_heading level1 col12" >Test</th>
#       <th id="T_ebbd5_level1_col13" class="col_heading level1 col13" >Train</th>
#       <th id="T_ebbd5_level1_col14" class="col_heading level1 col14" >Val</th>
#       <th id="T_ebbd5_level1_col15" class="col_heading level1 col15" >Test</th>
#       <th id="T_ebbd5_level1_col16" class="col_heading level1 col16" >Train</th>
#       <th id="T_ebbd5_level1_col17" class="col_heading level1 col17" >Val</th>
#       <th id="T_ebbd5_level1_col18" class="col_heading level1 col18" >Test</th>
#       <th id="T_ebbd5_level1_col19" class="col_heading level1 col19" >Train</th>
#       <th id="T_ebbd5_level1_col20" class="col_heading level1 col20" >Val</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Percentile</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebbd5_level0_row0" class="row_heading level0 row0" >min</th>
#       <td id="T_ebbd5_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_ebbd5_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_ebbd5_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_ebbd5_row0_col3" class="data row0 col3" >-1.20</td>
#       <td id="T_ebbd5_row0_col4" class="data row0 col4" >-1.20</td>
#       <td id="T_ebbd5_row0_col5" class="data row0 col5" >-1.20</td>
#       <td id="T_ebbd5_row0_col6" class="data row0 col6" >8.80</td>
#       <td id="T_ebbd5_row0_col7" class="data row0 col7" >8.80</td>
#       <td id="T_ebbd5_row0_col8" class="data row0 col8" >8.80</td>
#       <td id="T_ebbd5_row0_col9" class="data row0 col9" >-24.33</td>
#       <td id="T_ebbd5_row0_col10" class="data row0 col10" >-26.15</td>
#       <td id="T_ebbd5_row0_col11" class="data row0 col11" >-22.31</td>
#       <td id="T_ebbd5_row0_col12" class="data row0 col12" >0.00</td>
#       <td id="T_ebbd5_row0_col13" class="data row0 col13" >0.00</td>
#       <td id="T_ebbd5_row0_col14" class="data row0 col14" >0.00</td>
#       <td id="T_ebbd5_row0_col15" class="data row0 col15" >0.00</td>
#       <td id="T_ebbd5_row0_col16" class="data row0 col16" >0.00</td>
#       <td id="T_ebbd5_row0_col17" class="data row0 col17" >0.00</td>
#       <td id="T_ebbd5_row0_col18" class="data row0 col18" >0.00</td>
#       <td id="T_ebbd5_row0_col19" class="data row0 col19" >0.00</td>
#       <td id="T_ebbd5_row0_col20" class="data row0 col20" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_ebbd5_level0_row1" class="row_heading level0 row1" >25%</th>
#       <td id="T_ebbd5_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_ebbd5_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_ebbd5_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_ebbd5_row1_col3" class="data row1 col3" >12.44</td>
#       <td id="T_ebbd5_row1_col4" class="data row1 col4" >12.44</td>
#       <td id="T_ebbd5_row1_col5" class="data row1 col5" >12.44</td>
#       <td id="T_ebbd5_row1_col6" class="data row1 col6" >21.32</td>
#       <td id="T_ebbd5_row1_c

# %%
format_run_tables(app_trn,app_val,app_tst,'Appalachians')
# Out:
# <style type="text/css">
# #T_ce1d1 caption {
#   weight: bold;
#   font-size: 18px;
# }
# #T_ce1d1_row0_col0, #T_ce1d1_row0_col3, #T_ce1d1_row0_col6, #T_ce1d1_row0_col9, #T_ce1d1_row0_col12, #T_ce1d1_row0_col15, #T_ce1d1_row0_col18, #T_ce1d1_row1_col0, #T_ce1d1_row1_col3, #T_ce1d1_row1_col6, #T_ce1d1_row1_col9, #T_ce1d1_row1_col12, #T_ce1d1_row1_col15, #T_ce1d1_row1_col18, #T_ce1d1_row2_col0, #T_ce1d1_row2_col3, #T_ce1d1_row2_col6, #T_ce1d1_row2_col9, #T_ce1d1_row2_col12, #T_ce1d1_row2_col15, #T_ce1d1_row2_col18, #T_ce1d1_row3_col0, #T_ce1d1_row3_col3, #T_ce1d1_row3_col6, #T_ce1d1_row3_col9, #T_ce1d1_row3_col12, #T_ce1d1_row3_col15, #T_ce1d1_row3_col18, #T_ce1d1_row4_col0, #T_ce1d1_row4_col3, #T_ce1d1_row4_col6, #T_ce1d1_row4_col9, #T_ce1d1_row4_col12, #T_ce1d1_row4_col15, #T_ce1d1_row4_col18 {
#   background-color: #AAAAAA;
# }
# #T_ce1d1_row0_col1, #T_ce1d1_row0_col4, #T_ce1d1_row0_col7, #T_ce1d1_row0_col10, #T_ce1d1_row0_col13, #T_ce1d1_row0_col16, #T_ce1d1_row0_col19, #T_ce1d1_row1_col1, #T_ce1d1_row1_col4, #T_ce1d1_row1_col7, #T_ce1d1_row1_col10, #T_ce1d1_row1_col13, #T_ce1d1_row1_col16, #T_ce1d1_row1_col19, #T_ce1d1_row2_col1, #T_ce1d1_row2_col4, #T_ce1d1_row2_col7, #T_ce1d1_row2_col10, #T_ce1d1_row2_col13, #T_ce1d1_row2_col16, #T_ce1d1_row2_col19, #T_ce1d1_row3_col1, #T_ce1d1_row3_col4, #T_ce1d1_row3_col7, #T_ce1d1_row3_col10, #T_ce1d1_row3_col13, #T_ce1d1_row3_col16, #T_ce1d1_row3_col19, #T_ce1d1_row4_col1, #T_ce1d1_row4_col4, #T_ce1d1_row4_col7, #T_ce1d1_row4_col10, #T_ce1d1_row4_col13, #T_ce1d1_row4_col16, #T_ce1d1_row4_col19 {
#   background-color: #CCCCCC;
# }
# #T_ce1d1_row0_col2, #T_ce1d1_row0_col5, #T_ce1d1_row0_col8, #T_ce1d1_row0_col11, #T_ce1d1_row0_col14, #T_ce1d1_row0_col17, #T_ce1d1_row0_col20, #T_ce1d1_row1_col2, #T_ce1d1_row1_col5, #T_ce1d1_row1_col8, #T_ce1d1_row1_col11, #T_ce1d1_row1_col14, #T_ce1d1_row1_col17, #T_ce1d1_row1_col20, #T_ce1d1_row2_col2, #T_ce1d1_row2_col5, #T_ce1d1_row2_col8, #T_ce1d1_row2_col11, #T_ce1d1_row2_col14, #T_ce1d1_row2_col17, #T_ce1d1_row2_col20, #T_ce1d1_row3_col2, #T_ce1d1_row3_col5, #T_ce1d1_row3_col8, #T_ce1d1_row3_col11, #T_ce1d1_row3_col14, #T_ce1d1_row3_col17, #T_ce1d1_row3_col20, #T_ce1d1_row4_col2, #T_ce1d1_row4_col5, #T_ce1d1_row4_col8, #T_ce1d1_row4_col11, #T_ce1d1_row4_col14, #T_ce1d1_row4_col17, #T_ce1d1_row4_col20 {
#   background-color: #EEEEEE;
# }
# </style>
# <table id="T_ce1d1">
#   <caption>Appalachians</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce1d1_level0_col0" class="col_heading level0 col0" colspan="3">Slope (m/km)</th>
#       <th id="T_ce1d1_level0_col3" class="col_heading level0 col3" colspan="3">Elevation (m)</th>
#       <th id="T_ce1d1_level0_col6" class="col_heading level0 col6" colspan="3">Mean Width (m)</th>
#       <th id="T_ce1d1_level0_col9" class="col_heading level0 col9" colspan="3">Air Temp. (°C)</th>
#       <th id="T_ce1d1_level0_col12" class="col_heading level0 col12" colspan="3">SW Rad. (W/sq.m)</th>
#       <th id="T_ce1d1_level0_col15" class="col_heading level0 col15" colspan="3">Precip. (cm)</th>
#       <th id="T_ce1d1_level0_col18" class="col_heading level0 col18" colspan="3">Potential ET (cm)</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Partition</th>
#       <th id="T_ce1d1_level1_col0" class="col_heading level1 col0" >Test</th>
#       <th id="T_ce1d1_level1_col1" class="col_heading level1 col1" >Train</th>
#       <th id="T_ce1d1_level1_col2" class="col_heading level1 col2" >Val</th>
#       <th id="T_ce1d1_level1_col3" class="col_heading level1 col3" >Test</th>
#       <th id="T_ce1d1_level1_col4" class="col_heading level1 col4" >Train</th>
#       <th id="T_ce1d1_level1_col5" class="col_heading level1 col5" >Val</th>
#       <th id="T_ce1d1_level1_col6" class="col_heading level1 col6" >Test</th>
#       <th id="T_ce1d1_level1_col7" class="col_heading level1 col7" >Train</th>
#       <th id="T_ce1d1_level1_col8" class="col_heading level1 col8" >Val</th>
#       <th id="T_ce1d1_level1_col9" class="col_heading level1 col9" >Test</th>
#       <th id="T_ce1d1_level1_col10" class="col_heading level1 col10" >Train</th>
#       <th id="T_ce1d1_level1_col11" class="col_heading level1 col11" >Val</th>
#       <th id="T_ce1d1_level1_col12" class="col_heading level1 col12" >Test</th>
#       <th id="T_ce1d1_level1_col13" class="col_heading level1 col13" >Train</th>
#       <th id="T_ce1d1_level1_col14" class="col_heading level1 col14" >Val</th>
#       <th id="T_ce1d1_level1_col15" class="col_heading level1 col15" >Test</th>
#       <th id="T_ce1d1_level1_col16" class="col_heading level1 col16" >Train</th>
#       <th id="T_ce1d1_level1_col17" class="col_heading level1 col17" >Val</th>
#       <th id="T_ce1d1_level1_col18" class="col_heading level1 col18" >Test</th>
#       <th id="T_ce1d1_level1_col19" class="col_heading level1 col19" >Train</th>
#       <th id="T_ce1d1_level1_col20" class="col_heading level1 col20" >Val</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Percentile</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce1d1_level0_row0" class="row_heading level0 row0" >min</th>
#       <td id="T_ce1d1_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_ce1d1_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_ce1d1_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_ce1d1_row0_col3" class="data row0 col3" >39.49</td>
#       <td id="T_ce1d1_row0_col4" class="data row0 col4" >-1.20</td>
#       <td id="T_ce1d1_row0_col5" class="data row0 col5" >-1.20</td>
#       <td id="T_ce1d1_row0_col6" class="data row0 col6" >12.71</td>
#       <td id="T_ce1d1_row0_col7" class="data row0 col7" >8.80</td>
#       <td id="T_ce1d1_row0_col8" class="data row0 col8" >8.80</td>
#       <td id="T_ce1d1_row0_col9" class="data row0 col9" >-26.15</td>
#       <td id="T_ce1d1_row0_col10" class="data row0 col10" >-25.41</td>
#       <td id="T_ce1d1_row0_col11" class="data row0 col11" >-18.83</td>
#       <td id="T_ce1d1_row0_col12" class="data row0 col12" >0.00</td>
#       <td id="T_ce1d1_row0_col13" class="data row0 col13" >0.00</td>
#       <td id="T_ce1d1_row0_col14" class="data row0 col14" >0.00</td>
#       <td id="T_ce1d1_row0_col15" class="data row0 col15" >0.00</td>
#       <td id="T_ce1d1_row0_col16" class="data row0 col16" >0.00</td>
#       <td id="T_ce1d1_row0_col17" class="data row0 col17" >0.00</td>
#       <td id="T_ce1d1_row0_col18" class="data row0 col18" >0.00</td>
#       <td id="T_ce1d1_row0_col19" class="data row0 col19" >0.00</td>
#       <td id="T_ce1d1_row0_col20" class="data row0 col20" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_ce1d1_level0_row1" class="row_heading level0 row1" >25%</th>
#       <td id="T_ce1d1_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_ce1d1_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_ce1d1_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_ce1d1_row1_col3" class="data row1 col3" >97.25</td>
#       <td id="T_ce1d1_row1_col4" class="data row1 col4" >0.71</td>
#       <td id="T_ce1d1_row1_col5" class="data row1 col5" >0.71</td>
#       <td id="T_ce1d1_row1_col6" class="data row1 col6" >22.84</td>
#       <td id="T_ce1d1_ro

# %%
format_run_tables(head_trn,head_val,head_tst, 'Headwaters')
# Out:
# <style type="text/css">
# #T_e591e caption {
#   weight: bold;
#   font-size: 18px;
# }
# #T_e591e_row0_col0, #T_e591e_row0_col3, #T_e591e_row0_col6, #T_e591e_row0_col9, #T_e591e_row0_col12, #T_e591e_row0_col15, #T_e591e_row0_col18, #T_e591e_row1_col0, #T_e591e_row1_col3, #T_e591e_row1_col6, #T_e591e_row1_col9, #T_e591e_row1_col12, #T_e591e_row1_col15, #T_e591e_row1_col18, #T_e591e_row2_col0, #T_e591e_row2_col3, #T_e591e_row2_col6, #T_e591e_row2_col9, #T_e591e_row2_col12, #T_e591e_row2_col15, #T_e591e_row2_col18, #T_e591e_row3_col0, #T_e591e_row3_col3, #T_e591e_row3_col6, #T_e591e_row3_col9, #T_e591e_row3_col12, #T_e591e_row3_col15, #T_e591e_row3_col18, #T_e591e_row4_col0, #T_e591e_row4_col3, #T_e591e_row4_col6, #T_e591e_row4_col9, #T_e591e_row4_col12, #T_e591e_row4_col15, #T_e591e_row4_col18 {
#   background-color: #AAAAAA;
# }
# #T_e591e_row0_col1, #T_e591e_row0_col4, #T_e591e_row0_col7, #T_e591e_row0_col10, #T_e591e_row0_col13, #T_e591e_row0_col16, #T_e591e_row0_col19, #T_e591e_row1_col1, #T_e591e_row1_col4, #T_e591e_row1_col7, #T_e591e_row1_col10, #T_e591e_row1_col13, #T_e591e_row1_col16, #T_e591e_row1_col19, #T_e591e_row2_col1, #T_e591e_row2_col4, #T_e591e_row2_col7, #T_e591e_row2_col10, #T_e591e_row2_col13, #T_e591e_row2_col16, #T_e591e_row2_col19, #T_e591e_row3_col1, #T_e591e_row3_col4, #T_e591e_row3_col7, #T_e591e_row3_col10, #T_e591e_row3_col13, #T_e591e_row3_col16, #T_e591e_row3_col19, #T_e591e_row4_col1, #T_e591e_row4_col4, #T_e591e_row4_col7, #T_e591e_row4_col10, #T_e591e_row4_col13, #T_e591e_row4_col16, #T_e591e_row4_col19 {
#   background-color: #CCCCCC;
# }
# #T_e591e_row0_col2, #T_e591e_row0_col5, #T_e591e_row0_col8, #T_e591e_row0_col11, #T_e591e_row0_col14, #T_e591e_row0_col17, #T_e591e_row0_col20, #T_e591e_row1_col2, #T_e591e_row1_col5, #T_e591e_row1_col8, #T_e591e_row1_col11, #T_e591e_row1_col14, #T_e591e_row1_col17, #T_e591e_row1_col20, #T_e591e_row2_col2, #T_e591e_row2_col5, #T_e591e_row2_col8, #T_e591e_row2_col11, #T_e591e_row2_col14, #T_e591e_row2_col17, #T_e591e_row2_col20, #T_e591e_row3_col2, #T_e591e_row3_col5, #T_e591e_row3_col8, #T_e591e_row3_col11, #T_e591e_row3_col14, #T_e591e_row3_col17, #T_e591e_row3_col20, #T_e591e_row4_col2, #T_e591e_row4_col5, #T_e591e_row4_col8, #T_e591e_row4_col11, #T_e591e_row4_col14, #T_e591e_row4_col17, #T_e591e_row4_col20 {
#   background-color: #EEEEEE;
# }
# </style>
# <table id="T_e591e">
#   <caption>Headwaters</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e591e_level0_col0" class="col_heading level0 col0" colspan="3">Slope (m/km)</th>
#       <th id="T_e591e_level0_col3" class="col_heading level0 col3" colspan="3">Elevation (m)</th>
#       <th id="T_e591e_level0_col6" class="col_heading level0 col6" colspan="3">Mean Width (m)</th>
#       <th id="T_e591e_level0_col9" class="col_heading level0 col9" colspan="3">Air Temp. (°C)</th>
#       <th id="T_e591e_level0_col12" class="col_heading level0 col12" colspan="3">SW Rad. (W/sq.m)</th>
#       <th id="T_e591e_level0_col15" class="col_heading level0 col15" colspan="3">Precip. (cm)</th>
#       <th id="T_e591e_level0_col18" class="col_heading level0 col18" colspan="3">Potential ET (cm)</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Partition</th>
#       <th id="T_e591e_level1_col0" class="col_heading level1 col0" >Test</th>
#       <th id="T_e591e_level1_col1" class="col_heading level1 col1" >Train</th>
#       <th id="T_e591e_level1_col2" class="col_heading level1 col2" >Val</th>
#       <th id="T_e591e_level1_col3" class="col_heading level1 col3" >Test</th>
#       <th id="T_e591e_level1_col4" class="col_heading level1 col4" >Train</th>
#       <th id="T_e591e_level1_col5" class="col_heading level1 col5" >Val</th>
#       <th id="T_e591e_level1_col6" class="col_heading level1 col6" >Test</th>
#       <th id="T_e591e_level1_col7" class="col_heading level1 col7" >Train</th>
#       <th id="T_e591e_level1_col8" class="col_heading level1 col8" >Val</th>
#       <th id="T_e591e_level1_col9" class="col_heading level1 col9" >Test</th>
#       <th id="T_e591e_level1_col10" class="col_heading level1 col10" >Train</th>
#       <th id="T_e591e_level1_col11" class="col_heading level1 col11" >Val</th>
#       <th id="T_e591e_level1_col12" class="col_heading level1 col12" >Test</th>
#       <th id="T_e591e_level1_col13" class="col_heading level1 col13" >Train</th>
#       <th id="T_e591e_level1_col14" class="col_heading level1 col14" >Val</th>
#       <th id="T_e591e_level1_col15" class="col_heading level1 col15" >Test</th>
#       <th id="T_e591e_level1_col16" class="col_heading level1 col16" >Train</th>
#       <th id="T_e591e_level1_col17" class="col_heading level1 col17" >Val</th>
#       <th id="T_e591e_level1_col18" class="col_heading level1 col18" >Test</th>
#       <th id="T_e591e_level1_col19" class="col_heading level1 col19" >Train</th>
#       <th id="T_e591e_level1_col20" class="col_heading level1 col20" >Val</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Percentile</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e591e_level0_row0" class="row_heading level0 row0" >min</th>
#       <td id="T_e591e_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_e591e_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_e591e_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_e591e_row0_col3" class="data row0 col3" >222.67</td>
#       <td id="T_e591e_row0_col4" class="data row0 col4" >-1.20</td>
#       <td id="T_e591e_row0_col5" class="data row0 col5" >-1.20</td>
#       <td id="T_e591e_row0_col6" class="data row0 col6" >8.80</td>
#       <td id="T_e591e_row0_col7" class="data row0 col7" >10.79</td>
#       <td id="T_e591e_row0_col8" class="data row0 col8" >8.80</td>
#       <td id="T_e591e_row0_col9" class="data row0 col9" >-25.41</td>
#       <td id="T_e591e_row0_col10" class="data row0 col10" >-26.15</td>
#       <td id="T_e591e_row0_col11" class="data row0 col11" >-19.17</td>
#       <td id="T_e591e_row0_col12" class="data row0 col12" >0.00</td>
#       <td id="T_e591e_row0_col13" class="data row0 col13" >0.00</td>
#       <td id="T_e591e_row0_col14" class="data row0 col14" >0.00</td>
#       <td id="T_e591e_row0_col15" class="data row0 col15" >0.00</td>
#       <td id="T_e591e_row0_col16" class="data row0 col16" >0.00</td>
#       <td id="T_e591e_row0_col17" class="data row0 col17" >0.00</td>
#       <td id="T_e591e_row0_col18" class="data row0 col18" >0.00</td>
#       <td id="T_e591e_row0_col19" class="data row0 col19" >0.00</td>
#       <td id="T_e591e_row0_col20" class="data row0 col20" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e591e_level0_row1" class="row_heading level0 row1" >25%</th>
#       <td id="T_e591e_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_e591e_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_e591e_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_e591e_row1_col3" class="data row1 col3" >301.46</td>
#       <td id="T_e591e_row1_col4" class="data row1 col4" >6.31</td>
#       <td id="T_e591e_row1_col5" class="data row1 col5" >12.44</td>
#       <td id="T_e591e_row1_col6" class="data row1 col6" >21.65</td>
#       <td id="T_e591e_r

# %%
format_run_tables(coast_trn,coast_val,coast_tst,'Coastal')
# Out:
# <style type="text/css">
# #T_28c79 caption {
#   weight: bold;
#   font-size: 18px;
# }
# #T_28c79_row0_col0, #T_28c79_row0_col3, #T_28c79_row0_col6, #T_28c79_row0_col9, #T_28c79_row0_col12, #T_28c79_row0_col15, #T_28c79_row0_col18, #T_28c79_row1_col0, #T_28c79_row1_col3, #T_28c79_row1_col6, #T_28c79_row1_col9, #T_28c79_row1_col12, #T_28c79_row1_col15, #T_28c79_row1_col18, #T_28c79_row2_col0, #T_28c79_row2_col3, #T_28c79_row2_col6, #T_28c79_row2_col9, #T_28c79_row2_col12, #T_28c79_row2_col15, #T_28c79_row2_col18, #T_28c79_row3_col0, #T_28c79_row3_col3, #T_28c79_row3_col6, #T_28c79_row3_col9, #T_28c79_row3_col12, #T_28c79_row3_col15, #T_28c79_row3_col18, #T_28c79_row4_col0, #T_28c79_row4_col3, #T_28c79_row4_col6, #T_28c79_row4_col9, #T_28c79_row4_col12, #T_28c79_row4_col15, #T_28c79_row4_col18 {
#   background-color: #AAAAAA;
# }
# #T_28c79_row0_col1, #T_28c79_row0_col4, #T_28c79_row0_col7, #T_28c79_row0_col10, #T_28c79_row0_col13, #T_28c79_row0_col16, #T_28c79_row0_col19, #T_28c79_row1_col1, #T_28c79_row1_col4, #T_28c79_row1_col7, #T_28c79_row1_col10, #T_28c79_row1_col13, #T_28c79_row1_col16, #T_28c79_row1_col19, #T_28c79_row2_col1, #T_28c79_row2_col4, #T_28c79_row2_col7, #T_28c79_row2_col10, #T_28c79_row2_col13, #T_28c79_row2_col16, #T_28c79_row2_col19, #T_28c79_row3_col1, #T_28c79_row3_col4, #T_28c79_row3_col7, #T_28c79_row3_col10, #T_28c79_row3_col13, #T_28c79_row3_col16, #T_28c79_row3_col19, #T_28c79_row4_col1, #T_28c79_row4_col4, #T_28c79_row4_col7, #T_28c79_row4_col10, #T_28c79_row4_col13, #T_28c79_row4_col16, #T_28c79_row4_col19 {
#   background-color: #CCCCCC;
# }
# #T_28c79_row0_col2, #T_28c79_row0_col5, #T_28c79_row0_col8, #T_28c79_row0_col11, #T_28c79_row0_col14, #T_28c79_row0_col17, #T_28c79_row0_col20, #T_28c79_row1_col2, #T_28c79_row1_col5, #T_28c79_row1_col8, #T_28c79_row1_col11, #T_28c79_row1_col14, #T_28c79_row1_col17, #T_28c79_row1_col20, #T_28c79_row2_col2, #T_28c79_row2_col5, #T_28c79_row2_col8, #T_28c79_row2_col11, #T_28c79_row2_col14, #T_28c79_row2_col17, #T_28c79_row2_col20, #T_28c79_row3_col2, #T_28c79_row3_col5, #T_28c79_row3_col8, #T_28c79_row3_col11, #T_28c79_row3_col14, #T_28c79_row3_col17, #T_28c79_row3_col20, #T_28c79_row4_col2, #T_28c79_row4_col5, #T_28c79_row4_col8, #T_28c79_row4_col11, #T_28c79_row4_col14, #T_28c79_row4_col17, #T_28c79_row4_col20 {
#   background-color: #EEEEEE;
# }
# </style>
# <table id="T_28c79">
#   <caption>Coastal</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28c79_level0_col0" class="col_heading level0 col0" colspan="3">Slope (m/km)</th>
#       <th id="T_28c79_level0_col3" class="col_heading level0 col3" colspan="3">Elevation (m)</th>
#       <th id="T_28c79_level0_col6" class="col_heading level0 col6" colspan="3">Mean Width (m)</th>
#       <th id="T_28c79_level0_col9" class="col_heading level0 col9" colspan="3">Air Temp. (°C)</th>
#       <th id="T_28c79_level0_col12" class="col_heading level0 col12" colspan="3">SW Rad. (W/sq.m)</th>
#       <th id="T_28c79_level0_col15" class="col_heading level0 col15" colspan="3">Precip. (cm)</th>
#       <th id="T_28c79_level0_col18" class="col_heading level0 col18" colspan="3">Potential ET (cm)</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Partition</th>
#       <th id="T_28c79_level1_col0" class="col_heading level1 col0" >Test</th>
#       <th id="T_28c79_level1_col1" class="col_heading level1 col1" >Train</th>
#       <th id="T_28c79_level1_col2" class="col_heading level1 col2" >Val</th>
#       <th id="T_28c79_level1_col3" class="col_heading level1 col3" >Test</th>
#       <th id="T_28c79_level1_col4" class="col_heading level1 col4" >Train</th>
#       <th id="T_28c79_level1_col5" class="col_heading level1 col5" >Val</th>
#       <th id="T_28c79_level1_col6" class="col_heading level1 col6" >Test</th>
#       <th id="T_28c79_level1_col7" class="col_heading level1 col7" >Train</th>
#       <th id="T_28c79_level1_col8" class="col_heading level1 col8" >Val</th>
#       <th id="T_28c79_level1_col9" class="col_heading level1 col9" >Test</th>
#       <th id="T_28c79_level1_col10" class="col_heading level1 col10" >Train</th>
#       <th id="T_28c79_level1_col11" class="col_heading level1 col11" >Val</th>
#       <th id="T_28c79_level1_col12" class="col_heading level1 col12" >Test</th>
#       <th id="T_28c79_level1_col13" class="col_heading level1 col13" >Train</th>
#       <th id="T_28c79_level1_col14" class="col_heading level1 col14" >Val</th>
#       <th id="T_28c79_level1_col15" class="col_heading level1 col15" >Test</th>
#       <th id="T_28c79_level1_col16" class="col_heading level1 col16" >Train</th>
#       <th id="T_28c79_level1_col17" class="col_heading level1 col17" >Val</th>
#       <th id="T_28c79_level1_col18" class="col_heading level1 col18" >Test</th>
#       <th id="T_28c79_level1_col19" class="col_heading level1 col19" >Train</th>
#       <th id="T_28c79_level1_col20" class="col_heading level1 col20" >Val</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Percentile</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28c79_level0_row0" class="row_heading level0 row0" >min</th>
#       <td id="T_28c79_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_28c79_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_28c79_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_28c79_row0_col3" class="data row0 col3" >-1.20</td>
#       <td id="T_28c79_row0_col4" class="data row0 col4" >39.49</td>
#       <td id="T_28c79_row0_col5" class="data row0 col5" >-1.20</td>
#       <td id="T_28c79_row0_col6" class="data row0 col6" >10.79</td>
#       <td id="T_28c79_row0_col7" class="data row0 col7" >8.80</td>
#       <td id="T_28c79_row0_col8" class="data row0 col8" >8.80</td>
#       <td id="T_28c79_row0_col9" class="data row0 col9" >-23.83</td>
#       <td id="T_28c79_row0_col10" class="data row0 col10" >-26.15</td>
#       <td id="T_28c79_row0_col11" class="data row0 col11" >-19.17</td>
#       <td id="T_28c79_row0_col12" class="data row0 col12" >0.00</td>
#       <td id="T_28c79_row0_col13" class="data row0 col13" >0.00</td>
#       <td id="T_28c79_row0_col14" class="data row0 col14" >0.00</td>
#       <td id="T_28c79_row0_col15" class="data row0 col15" >0.00</td>
#       <td id="T_28c79_row0_col16" class="data row0 col16" >0.00</td>
#       <td id="T_28c79_row0_col17" class="data row0 col17" >0.00</td>
#       <td id="T_28c79_row0_col18" class="data row0 col18" >0.00</td>
#       <td id="T_28c79_row0_col19" class="data row0 col19" >0.00</td>
#       <td id="T_28c79_row0_col20" class="data row0 col20" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_28c79_level0_row1" class="row_heading level0 row1" >25%</th>
#       <td id="T_28c79_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_28c79_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_28c79_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_28c79_row1_col3" class="data row1 col3" >0.05</td>
#       <td id="T_28c79_row1_col4" class="data row1 col4" >120.91</td>
#       <td id="T_28c79_row1_col5" class="data row1 col5" >12.44</td>
#       <td id="T_28c79_row1_col6" class="data row1 col6" >19.93</td>
#       <td id="T_28c79_row1_

# %%
segs = gpd.read_file('data_DRB/DRB_spatial/segs/segs.shp')

def calc_diff_seg(tst,trn):
    tst_seg = tst[['seg_tave_air','sg_d_nt']].loc[tst.month.isin([6,7,8])].groupby(['sg_d_nt']).median()
    trn_seg = trn[['seg_tave_air','sg_d_nt']].loc[trn.month.isin([6,7,8])].groupby(['sg_d_nt']).median()
    return tst_seg-trn_seg

def calc_diff_seg_drought(tst,trn):
    tst['year']=tst.date.dt.year.where(tst.date.dt.month < 10,tst.date.dt.year + 1)
    trn['year']=trn.date.dt.year.where(trn.date.dt.month < 10,trn.date.dt.year + 1)
    tst_seg = tst[['year','sg_d_nt','seg_rain']].groupby(['year','sg_d_nt']).sum().groupby(['sg_d_nt']).median()
    trn_seg = trn[['year','sg_d_nt','seg_rain']].groupby(['year','sg_d_nt']).sum().groupby(['sg_d_nt']).median()
    diff = -1*(tst_seg-trn_seg)
    return diff

temp_diff_seg = calc_diff_seg(lto_max_tst,lto_max_trn)
temp_diff_sf = temp_diff_seg.reset_index().merge(segs).set_geometry('geometry')
fig, ax = plt.subplots(1,2,figsize=(5,5.5),dpi=200)

temp_diff_sf.plot(column='seg_tave_air',ax=ax[0],legend=True, legend_kwds={"label":"°C", 'location':'bottom','anchor':(0.5,2)})

ax[0].set_axis_off()
ax[0].set_title('Temperature\nDifference')

drought_diff_seg = calc_diff_seg_drought(drought_tst, drought_trn)
drought_diff_sf = drought_diff_seg.reset_index().merge(segs).set_geometry('geometry')

drought_diff_sf.plot(column='seg_rain',ax=ax[1],legend=True,legend_kwds={"label":"m/yr", 'location':'bottom','anchor':(0.5,2)})
ax[1].set_axis_off()
ax[1].set_title('Precipitation\nDifference')
plt.savefig('results/figures/trn_tst_precip_temp_diff.png')

# %%
# Out:
# 'Train'
